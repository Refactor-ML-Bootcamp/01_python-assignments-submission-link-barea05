# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data = pd.read_csv("advertising.csv")
data
# Out:
#         TV  Radio  Newspaper  Sales
# 0    230.1   37.8       69.2   22.1
# 1     44.5   39.3       45.1   10.4
# 2     17.2   45.9       69.3   12.0
# 3    151.5   41.3       58.5   16.5
# 4    180.8   10.8       58.4   17.9
# ..     ...    ...        ...    ...
# 195   38.2    3.7       13.8    7.6
# 196   94.2    4.9        8.1   14.0
# 197  177.0    9.3        6.4   14.8
# 198  283.6   42.0       66.2   25.5
# 199  232.1    8.6        8.7   18.4
#
# [200 rows x 4 columns]

# %%
tv_count = data.TV.sum()
tv_count
# Out:
# 29408.5

# %%
Radio_count = data.Radio.sum()
Radio_count
# Out:
# 4652.800000000001

# %%
Newspaper_count  = data.Newspaper.sum()
Newspaper_count
# Out:
# 6110.799999999999

# %%
Sales_count =  data.Sales.sum()
Sales_count
# Out:
# 3026.1000000000004

# %%
data.describe()
# Out:
#                TV       Radio   Newspaper       Sales
# count  200.000000  200.000000  200.000000  200.000000
# mean   147.042500   23.264000   30.554000   15.130500
# std     85.854236   14.846809   21.778621    5.283892
# min      0.700000    0.000000    0.300000    1.600000
# 25%     74.375000    9.975000   12.750000   11.000000
# 50%    149.750000   22.900000   25.750000   16.000000
# 75%    218.825000   36.525000   45.100000   19.050000
# max    296.400000   49.600000  114.000000   27.000000

# %%
#data cleaning

# %%
data.isnull().sum()
# Out:
# TV           0
# Radio        0
# Newspaper    0
# Sales        0
# dtype: int64

# %%
data.dtypes
# Out:
# TV           float64
# Radio        float64
# Newspaper    float64
# Sales        float64
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 200 entries, 0 to 199
# Data columns (total 4 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   TV         200 non-null    float64
#  1   Radio      200 non-null    float64
#  2   Newspaper  200 non-null    float64
#  3   Sales      200 non-null    float64
# dtypes: float64(4)
# memory usage: 6.4 KB

# %%
#perform eda

# %%
sns.set_theme(style="ticks")
sns.pairplot(data, hue="Sales")
# Out:
# C:\Users\Dhivakar\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Dhivakar\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Dhivakar\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Dhivakar\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# C:\Users\Dhivakar\anaconda3\lib\site-packages\seaborn\distributions.py:306: UserWarning: Dataset has 0 variance; skipping density estimate.
#   warnings.warn(msg, UserWarning)
# ...

# %%
# Outlier Analysis
fig, axs = plt.subplots(4, figsize = (7,7))
plt1 = sns.boxplot(data['TV'], ax = axs[0])
plt2 = sns.boxplot(data['Newspaper'], ax = axs[1])
plt3 = sns.boxplot(data['Radio'], ax = axs[2])
plt3 = sns.boxplot(data['Sales'], ax = axs[3])
plt.tight_layout()
# Out:
# C:\Users\Dhivakar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Dhivakar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# C:\Users\Dhivakar\anaconda3\lib\site-packages\seaborn\_decorators.py:36: FutureWarning: Pass the following variable as a keyword arg: x. From version 0.12, the only valid positional argument will be `data`, and passing other arguments without an explicit keyword will result in an error or misinterpretation.
#   warnings.warn(
# ...

# %%
sns.pairplot(data, x_vars=['TV', 'Newspaper', 'Radio'], y_vars='Sales', height=3, aspect=1, kind='scatter')

# %%
sns.histplot(x= data.TV, y= data["Sales"], binwidth= 5)
# Out:
# <AxesSubplot:xlabel='TV', ylabel='Sales'>

# %%
sns.histplot(x= data.Newspaper, y= data["Sales"], binwidth= 5)
# Out:
# <AxesSubplot:xlabel='Newspaper', ylabel='Sales'>

# %%
sns.histplot(x= data.Radio, y= data["Sales"], binwidth= 5)
# Out:
# <AxesSubplot:xlabel='Radio', ylabel='Sales'>

# %%
sns.histplot(data["TV"])
# Out:
# <AxesSubplot:xlabel='TV', ylabel='Count'>

# %%
sns.histplot(data["Newspaper"])
# Out:
# <AxesSubplot:xlabel='Newspaper', ylabel='Count'>

# %%
sns.histplot(x = data["Radio"])
# Out:
# <AxesSubplot:xlabel='Radio', ylabel='Count'>

# %%
sns.histplot(data["Sales"])
# Out:
# <AxesSubplot:xlabel='Sales', ylabel='Count'>

# %%
sns.histplot(data)
# Out:
# <AxesSubplot:ylabel='Count'>

# %%
sns.heatmap(data.corr(), cmap="YlGnBu", annot = True)
# Out:
# <AxesSubplot:>

# %%
plt.plot(data, data["Newspaper"], 'r--', data, data["TV"], 'bs', data, data["Radio"], 'g^')
plt.show()

# %%
plt.plot(data["Newspaper"], 'r--', data["TV"], 'bs',data["Radio"], 'g^')
plt.show()
